# %%
import pandas as pd

#csv data file
csv_file_path1 = 'import/2018_Chase_Loans.csv'
csv_file_path2 = 'import/2019_Chase_Loans.csv'
csv_file_path3 = 'import/2020_Chase_Loans.csv'
csv_file_path4 = 'import/2021_Chase_Loans.csv'
csv_file_path5 = 'import/2022_Chase_Loans.csv'

#read into dataframe
df = pd.read_csv(csv_file_path5)

#display
df
# Out:
# C:\Users\sbenn\AppData\Local\Temp\ipykernel_18620\2397237359.py:11: DtypeWarning: Columns (62,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path5)
#         activity_year                   lei  loan_type  loan_purpose  \
# 0                2022  7H6GLXDRUGQFU57RNE97          1             1
# 1                2022  7H6GLXDRUGQFU57RNE97          1             1
# 2                2022  7H6GLXDRUGQFU57RNE97          1             1
# 3                2022  7H6GLXDRUGQFU57RNE97          1            32
# 4                2022  7H6GLXDRUGQFU57RNE97          1             1
# ...               ...                   ...        ...           ...
# 243076           2022  7H6GLXDRUGQFU57RNE97          1            32
# 243077           2022  7H6GLXDRUGQFU57RNE97          1            31
# 243078           2022  7H6GLXDRUGQFU57RNE97          1            31
# 243079           2022  7H6GLXDRUGQFU57RNE97          1            31
# 243080           2022  7H6GLXDRUGQFU57RNE97          1            32
#
#         preapproval  construction_method  occupancy_type  loan_amount  \
# 0                 2                    1               1       415000
# 1                 2                    1               1       405000
# 2                 2                    1               1       375000
# 3                 2                    1               1       235000
# 4                 2                    1               3       235000
# ...             ...                  ...             ...          ...
# 243076            2                    1               1       605000
# 243077            2                    1               1       355000
# 243078            2                    1               1       235000
# 243079            2                    1               3       395000
# 243080            2                    1               1       385000
#
#         action_taken state_code  ...  submission_of_application  \
# 0                  6         MI  ...                          3
# 1                  6         TX  ...                          3
# 2                  6         NY  ...                          3
# 3                  6         MO  ...                          3
# 4                  6         NC  ...                          3
# ...              ...        ...  ...                        ...
# 243076             6         CA  ...                          3
# 243077             6         AZ  ...                          3
# 243078             6         WA  ...                          3
# 243079             6         VA  ...                          3
# 243080             6         CA  ...                          3
#
#         initially_payable_to_institution  aus_1  aus_2  aus_3  aus_4  aus_5  \
# 0                                      3      6    NaN    NaN    NaN    NaN
# 1                                      3      6    NaN    NaN    NaN    NaN
# 2                                      3      6    NaN    NaN    NaN    NaN
# 3                                      3      6    NaN    NaN    NaN    NaN
# 4                                      3      6    NaN    NaN    NaN    NaN
# ...                                  ...    ...    ...    ...    ...    ...
# 243076                                 3      6    NaN    NaN    NaN    NaN
# 243077                                 3      6    NaN    NaN    NaN    NaN
# 243078                                 3      6    NaN    NaN    NaN    NaN
# 243079                                 3      6    NaN    NaN    NaN    NaN
# 243080                                 3      6    NaN    NaN    NaN    NaN
#
#         reverse_mortgage  open_end_line_of_credit  \
# 0                      2                        2
# 1                      2                        2
# 2                      2                        2
# 3                      2                        2
# 4                      2                        2
# ...                  ...                      ...
# 243076                 2                        2
# 243077                 2                        2
# 243078                 2                        2
# 243079                 2                        2
# 243080                 2                        2
#
#         business_or_commercial_purpose
# 0                                    2
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    1
# ...                                ...
# 243076                               2
# 243077                               2
# 243078                               2
# 243079                               1
# 243080                               2
#
# [243081 rows x 85 columns]

# %%
#drop columns that we do not need/want or contain zero data
#shockingly large amount of the columns were not used or contained the same value regardless of outcome

to_be_dropped = ['lei', 
'preapproval', 'purchaser_type', 'rate_spread', 'denial_reason_1', 'denial_reason_2', 'denial_reason_3', 'denial_reason_4',
'total_points_and_fees', 'prepayment_penalty_term', 'debt_to_income_ratio', 'combined_loan_to_value_ratio',
'lien_status', 'applicant_credit_scoring_model', 'co_applicant_credit_scoring_model', 'hoepa_status',
'applicant_ethnicity_1','applicant_ethnicity_2','applicant_ethnicity_3','applicant_ethnicity_4','applicant_ethnicity_5',
'co_applicant_ethnicity_1','co_applicant_ethnicity_2','co_applicant_ethnicity_3','co_applicant_ethnicity_4',
'co_applicant_ethnicity_5','applicant_ethnicity_observed','co_applicant_ethnicity_observed','applicant_race_1',
'applicant_race_2','applicant_race_3','applicant_race_4','applicant_race_5','co_applicant_race_1',
'co_applicant_race_2','co_applicant_race_3','co_applicant_race_4','co_applicant_race_5','applicant_race_observed',
'co_applicant_race_observed', 'applicant_sex','co_applicant_sex','applicant_sex_observed','co_applicant_sex_observed',
'applicant_age','applicant_age_above_62','co_applicant_age','co_applicant_age_above_62', 'submission_of_application',
'balloon_payment', 'interest_only_payment', 'negative_amortization', 'other_non_amortizing_features', 'initially_payable_to_institution',
'multifamily_affordable_units', 'aus_1', 'aus_2', 'aus_3', 'aus_4', 'aus_5', 'reverse_mortgage', 'open_end_line_of_credit',
'manufactured_home_secured_property_type', 'manufactured_home_land_property_interest','census_tract',
'origination_charges', 'discount_points', 'lender_credits','intro_rate_period']

df = df.drop(columns=to_be_dropped)

df
# Out:
#         activity_year  loan_type  loan_purpose  construction_method  \
# 0                2022          1             1                    1
# 1                2022          1             1                    1
# 2                2022          1             1                    1
# 3                2022          1            32                    1
# 4                2022          1             1                    1
# ...               ...        ...           ...                  ...
# 243076           2022          1            32                    1
# 243077           2022          1            31                    1
# 243078           2022          1            31                    1
# 243079           2022          1            31                    1
# 243080           2022          1            32                    1
#
#         occupancy_type  loan_amount  action_taken state_code  county_code  \
# 0                    1       415000             6         MI      26099.0
# 1                    1       405000             6         TX      48113.0
# 2                    1       375000             6         NY      36047.0
# 3                    1       235000             6         MO      29189.0
# 4                    3       235000             6         NC      37183.0
# ...                ...          ...           ...        ...          ...
# 243076               1       605000             6         CA       6059.0
# 243077               1       355000             6         AZ       4013.0
# 243078               1       235000             6         WA      53033.0
# 243079               3       395000             6         VA      51107.0
# 243080               1       385000             6         CA       6079.0
#
#         income  total_loan_costs  interest_rate  loan_term  property_value  \
# 0        119.0           4414.66          5.875      360.0        435000.0
# 1         97.0           5230.50          3.500      360.0        425000.0
# 2        152.0           7841.13          2.875      360.0        505000.0
# 3         61.0           1938.08          3.750      360.0        375000.0
# 4        246.0               NaN          4.000      360.0        295000.0
# ...        ...               ...            ...        ...             ...
# 243076   100.0           7088.30          3.375      360.0        865000.0
# 243077    91.0           6258.24          3.250      360.0        515000.0
# 243078    45.0           3060.52          3.625      360.0        805000.0
# 243079   104.0               NaN          4.250      360.0        615000.0
# 243080    98.0           3703.06          3.750      180.0       1015000.0
#
#        total_units  business_or_commercial_purpose
# 0                1                               2
# 1                1                               2
# 2                1                               2
# 3                1                               2
# 4                1                               1
# ...            ...                             ...
# 243076           1                               2
# 243077           1                               2
# 243078           1                               2
# 243079           1                               1
# 243080           1                               2
#
# [243081 rows x 16 columns]

# %%
#converts string to numeric
df['income'] = pd.to_numeric(df['income'])

# Multiply the 'income' values by 1000 so its more human readable
df['income'] *= 1000

# %%
#only keep rows with loans approved or denied
df = df[df['action_taken'].isin([2,3,5,6,7,8])]

#only keep actual home loans
df = df[df['loan_purpose'].isin([1])]

#fill blanks with zeros
df = df.fillna(0)

df
# Out:
#         activity_year  loan_type  loan_purpose  construction_method  \
# 0                2022          1             1                    1
# 1                2022          1             1                    1
# 2                2022          1             1                    1
# 4                2022          1             1                    1
# 5                2022          1             1                    1
# ...               ...        ...           ...                  ...
# 242931           2022          1             1                    1
# 242936           2022          1             1                    1
# 243005           2022          1             1                    1
# 243015           2022          1             1                    1
# 243044           2022          1             1                    1
#
#         occupancy_type  loan_amount  action_taken state_code  county_code  \
# 0                    1       415000             6         MI      26099.0
# 1                    1       405000             6         TX      48113.0
# 2                    1       375000             6         NY      36047.0
# 4                    3       235000             6         NC      37183.0
# 5                    3       255000             6         NC      37183.0
# ...                ...          ...           ...        ...          ...
# 242931               1       205000             6         GA      13121.0
# 242936               1       545000             6         AZ       4013.0
# 243005               1       355000             6         CA       6085.0
# 243015               1       345000             6         OR      41019.0
# 243044               3       305000             6         NC      37119.0
#
#            income  total_loan_costs  interest_rate  loan_term  property_value  \
# 0        119000.0           4414.66          5.875      360.0        435000.0
# 1         97000.0           5230.50          3.500      360.0        425000.0
# 2        152000.0           7841.13          2.875      360.0        505000.0
# 4        246000.0              0.00          4.000      360.0        295000.0
# 5        246000.0              0.00          4.250      360.0        325000.0
# ...           ...               ...            ...        ...             ...
# 242931   258000.0           8361.45          4.125      360.0        385000.0
# 242936   310000.0           5014.23          3.375      360.0        685000.0
# 243005   155000.0           4647.45          4.750      360.0        975000.0
# 243015   132000.0           8419.60          3.750      360.0        435000.0
# 243044  1160000.0              0.00          4.375      360.0        515000.0
#
#        total_units  business_or_commercial_purpose
# 0                1                               2
# 1                1                               2
# 2                1                               2
# 4                1                               1
# 5                1                               1
# ...            ...                             ...
# 242931           1                               2
# 242936           1                               2
# 243005           1                               2
# 243015           1                               2
# 243044           1                               1
#
# [63025 rows x 16 columns]

# %%
#maps out our loan_type to match the key values
mapping = {
    1: 'Conventional', 
    2: 'FHA Insured', 
    3: 'VA Guaranteed', 
    4: 'Farm USDA'
}

#replace  map values
df['loan_type'] = df['loan_type'].replace(mapping)

#limits to Conventional loans
df = df[df['loan_type'].isin(['Conventional'])]

# %%
#maps out our loan_purpose to the key values
loan_purpose_mapping = {
    1: 'Home Purchase',
    2: 'Home Improvement',
    31: 'Refinancing',
    32: 'Cash-out refinancing',
    4: 'Other Purpose',
    5: 'Not Applicable'
}

#replace  map values
df['loan_purpose'] = df['loan_purpose'].replace(loan_purpose_mapping)

df
# Out:
# C:\Users\sbenn\AppData\Local\Temp\ipykernel_18620\1397660757.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loan_purpose'] = df['loan_purpose'].replace(loan_purpose_mapping)
#         activity_year     loan_type   loan_purpose  construction_method  \
# 0                2022  Conventional  Home Purchase                    1
# 1                2022  Conventional  Home Purchase                    1
# 2                2022  Conventional  Home Purchase                    1
# 4                2022  Conventional  Home Purchase                    1
# 5                2022  Conventional  Home Purchase                    1
# ...               ...           ...            ...                  ...
# 242931           2022  Conventional  Home Purchase                    1
# 242936           2022  Conventional  Home Purchase                    1
# 243005           2022  Conventional  Home Purchase                    1
# 243015           2022  Conventional  Home Purchase                    1
# 243044           2022  Conventional  Home Purchase                    1
#
#         occupancy_type  loan_amount  action_taken state_code  county_code  \
# 0                    1       415000             6         MI      26099.0
# 1                    1       405000             6         TX      48113.0
# 2                    1       375000             6         NY      36047.0
# 4                    3       235000             6         NC      37183.0
# 5                    3       255000             6         NC      37183.0
# ...                ...          ...           ...        ...          ...
# 242931               1       205000             6         GA      13121.0
# 242936               1       545000             6         AZ       4013.0
# 243005               1       355000             6         CA       6085.0
# 243015               1       345000             6         OR      41019.0
# 243044               3       305000             6         NC      37119.0
#
#            income  total_loan_costs  interest_rate  loan_term  property_value  \
# 0        119000.0           4414.66          5.875      360.0        435000.0
# 1         97000.0           5230.50          3.500      360.0        425000.0
# 2        152000.0           7841.13          2.875      360.0        505000.0
# 4        246000.0              0.00          4.000      360.0        295000.0
# 5        246000.0              0.00          4.250      360.0        325000.0
# ...           ...               ...            ...        ...             ...
# 242931   258000.0           8361.45          4.125      360.0        385000.0
# 242936   310000.0           5014.23          3.375      360.0        685000.0
# 243005   155000.0           4647.45          4.750      360.0        975000.0
# 243015   132000.0           8419.60          3.750      360.0        435000.0
# 243044  1160000.0              0.00          4.375      360.0        515000.0
#
#        total_units  business_or_commercial_purpose
# 0                1                               2
# 1                1                               2
# 2                1                               2
# 4                1                               1
# 5                1                               1
# ...            ...                             ...
# 242931           1                               2
# 242936           1                               2
# 243005           1                               2
# 243015           1                               2
# 243044           1                               1
#
# [60868 rows x 16 columns]

# %%
#maps out our construction_method to the key values
mapping = {
    1: 'Site-Built', 
    2: 'Manufactured-Home'
}

#replace  map values
df['construction_method'] = df['construction_method'].replace(mapping)

df
# Out:
# C:\Users\sbenn\AppData\Local\Temp\ipykernel_18620\1992423284.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['construction_method'] = df['construction_method'].replace(mapping)
#         activity_year     loan_type   loan_purpose construction_method  \
# 0                2022  Conventional  Home Purchase          Site-Built
# 1                2022  Conventional  Home Purchase          Site-Built
# 2                2022  Conventional  Home Purchase          Site-Built
# 4                2022  Conventional  Home Purchase          Site-Built
# 5                2022  Conventional  Home Purchase          Site-Built
# ...               ...           ...            ...                 ...
# 242931           2022  Conventional  Home Purchase          Site-Built
# 242936           2022  Conventional  Home Purchase          Site-Built
# 243005           2022  Conventional  Home Purchase          Site-Built
# 243015           2022  Conventional  Home Purchase          Site-Built
# 243044           2022  Conventional  Home Purchase          Site-Built
#
#         occupancy_type  loan_amount  action_taken state_code  county_code  \
# 0                    1       415000             6         MI      26099.0
# 1                    1       405000             6         TX      48113.0
# 2                    1       375000             6         NY      36047.0
# 4                    3       235000             6         NC      37183.0
# 5                    3       255000             6         NC      37183.0
# ...                ...          ...           ...        ...          ...
# 242931               1       205000             6         GA      13121.0
# 242936               1       545000             6         AZ       4013.0
# 243005               1       355000             6         CA       6085.0
# 243015               1       345000             6         OR      41019.0
# 243044               3       305000             6         NC      37119.0
#
#            income  total_loan_costs  interest_rate  loan_term  property_value  \
# 0        119000.0           4414.66          5.875      360.0        435000.0
# 1         97000.0           5230.50          3.500      360.0        425000.0
# 2        152000.0           7841.13          2.875      360.0        505000.0
# 4        246000.0              0.00          4.000      360.0        295000.0
# 5        246000.0              0.00          4.250      360.0        325000.0
# ...           ...               ...            ...        ...             ...
# 242931   258000.0           8361.45          4.125      360.0        385000.0
# 242936   310000.0           5014.23          3.375      360.0        685000.0
# 243005   155000.0           4647.45          4.750      360.0        975000.0
# 243015   132000.0           8419.60          3.750      360.0        435000.0
# 243044  1160000.0              0.00          4.375      360.0        515000.0
#
#        total_units  business_or_commercial_purpose
# 0                1                               2
# 1                1                               2
# 2                1                               2
# 4                1                               1
# 5                1                               1
# ...            ...                             ...
# 242931           1                               2
# 242936           1                               2
# 243005           1                               2
# 243015           1                               2
# 243044           1                               1
#
# [60868 rows x 16 columns]

# %%
#maps out our occupancy_type to the key values
mapping = {
    1: 'Principal-residence', 
    2: 'Second-residence', 
    3: 'Investment-property'
}

#replace  map values
df['occupancy_type'] = df['occupancy_type'].replace(mapping)

df
# Out:
# C:\Users\sbenn\AppData\Local\Temp\ipykernel_18620\3992442694.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['occupancy_type'] = df['occupancy_type'].replace(mapping)
#         activity_year     loan_type   loan_purpose construction_method  \
# 0                2022  Conventional  Home Purchase          Site-Built
# 1                2022  Conventional  Home Purchase          Site-Built
# 2                2022  Conventional  Home Purchase          Site-Built
# 4                2022  Conventional  Home Purchase          Site-Built
# 5                2022  Conventional  Home Purchase          Site-Built
# ...               ...           ...            ...                 ...
# 242931           2022  Conventional  Home Purchase          Site-Built
# 242936           2022  Conventional  Home Purchase          Site-Built
# 243005           2022  Conventional  Home Purchase          Site-Built
# 243015           2022  Conventional  Home Purchase          Site-Built
# 243044           2022  Conventional  Home Purchase          Site-Built
#
#              occupancy_type  loan_amount  action_taken state_code  \
# 0       Principal-residence       415000             6         MI
# 1       Principal-residence       405000             6         TX
# 2       Principal-residence       375000             6         NY
# 4       Investment-property       235000             6         NC
# 5       Investment-property       255000             6         NC
# ...                     ...          ...           ...        ...
# 242931  Principal-residence       205000             6         GA
# 242936  Principal-residence       545000             6         AZ
# 243005  Principal-residence       355000             6         CA
# 243015  Principal-residence       345000             6         OR
# 243044  Investment-property       305000             6         NC
#
#         county_code     income  total_loan_costs  interest_rate  loan_term  \
# 0           26099.0   119000.0           4414.66          5.875      360.0
# 1           48113.0    97000.0           5230.50          3.500      360.0
# 2           36047.0   152000.0           7841.13          2.875      360.0
# 4           37183.0   246000.0              0.00          4.000      360.0
# 5           37183.0   246000.0              0.00          4.250      360.0
# ...             ...        ...               ...            ...        ...
# 242931      13121.0   258000.0           8361.45          4.125      360.0
# 242936       4013.0   310000.0           5014.23          3.375      360.0
# 243005       6085.0   155000.0           4647.45          4.750      360.0
# 243015      41019.0   132000.0           8419.60          3.750      360.0
# 243044      37119.0  1160000.0              0.00          4.375      360.0
#
#         property_value total_units  business_or_commercial_purpose
# 0             435000.0           1                               2
# 1             425000.0           1                               2
# 2             505000.0           1                               2
# 4             295000.0           1                               1
# 5             325000.0           1                               1
# ...                ...         ...                             ...
# 242931        385000.0           1                               2
# 242936        685000.0           1                               2
# 243005        975000.0           1                               2
# 243015        435000.0           1                               2
# 243044        515000.0           1                               1
#
# [60868 rows x 16 columns]

# %%
#maps out our business_or_commercial_purpose to the key values
mapping = {
    1: 'Business', 
    2: 'Residence'
}

#replace  map values
df['business_or_commercial_purpose'] = df['business_or_commercial_purpose'].replace(mapping)

#limits our data to only Residences
df = df[df['business_or_commercial_purpose'].isin(['Residence'])]
# Out:
# C:\Users\sbenn\AppData\Local\Temp\ipykernel_18620\4017642300.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['business_or_commercial_purpose'] = df['business_or_commercial_purpose'].replace(mapping)

# %%
#maps out our action_taken to the key values
mapping = {
    1: 'Denied',  #removed
    2: 'Approved',  #approved
    3: 'Denied',  #denied
    4: 'Denied',  #removed
    5: 'Denied',  #denied
    6: 'Approved',  #approved
    7: 'Denied',  #denied
    8: 'Approved'   #approved
}
#replace  map values
df['action_taken'] = df['action_taken'].replace(mapping)

df
# Out:
# C:\Users\sbenn\AppData\Local\Temp\ipykernel_18620\2393496195.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['action_taken'] = df['action_taken'].replace(mapping)
#         activity_year     loan_type   loan_purpose construction_method  \
# 0                2022  Conventional  Home Purchase          Site-Built
# 1                2022  Conventional  Home Purchase          Site-Built
# 2                2022  Conventional  Home Purchase          Site-Built
# 10               2022  Conventional  Home Purchase          Site-Built
# 12               2022  Conventional  Home Purchase          Site-Built
# ...               ...           ...            ...                 ...
# 242929           2022  Conventional  Home Purchase          Site-Built
# 242931           2022  Conventional  Home Purchase          Site-Built
# 242936           2022  Conventional  Home Purchase          Site-Built
# 243005           2022  Conventional  Home Purchase          Site-Built
# 243015           2022  Conventional  Home Purchase          Site-Built
#
#              occupancy_type  loan_amount action_taken state_code  county_code  \
# 0       Principal-residence       415000     Approved         MI      26099.0
# 1       Principal-residence       405000     Approved         TX      48113.0
# 2       Principal-residence       375000     Approved         NY      36047.0
# 10      Principal-residence       265000     Approved         TX      48201.0
# 12      Principal-residence       225000     Approved         MO      29183.0
# ...                     ...          ...          ...        ...          ...
# 242929  Principal-residence       295000     Approved         FL      12057.0
# 242931  Principal-residence       205000     Approved         GA      13121.0
# 242936  Principal-residence       545000     Approved         AZ       4013.0
# 243005  Principal-residence       355000     Approved         CA       6085.0
# 243015  Principal-residence       345000     Approved         OR      41019.0
#
#           income  total_loan_costs  interest_rate  loan_term  property_value  \
# 0       119000.0           4414.66          5.875      360.0        435000.0
# 1        97000.0           5230.50          3.500      360.0        425000.0
# 2       152000.0           7841.13          2.875      360.0        505000.0
# 10      138000.0          11698.72          3.875      360.0        335000.0
# 12       89000.0           3848.86          4.125      360.0        255000.0
# ...          ...               ...            ...        ...             ...
# 242929   58000.0           8346.79          4.000      360.0        375000.0
# 242931  258000.0           8361.45          4.125      360.0        385000.0
# 242936  310000.0           5014.23          3.375      360.0        685000.0
# 243005  155000.0           4647.45          4.750      360.0        975000.0
# 243015  132000.0           8419.60          3.750      360.0        435000.0
#
#        total_units business_or_commercial_purpose
# 0                1                      Residence
# 1                1                      Residence
# 2                1                      Residence
# 10               1                      Residence
# 12               1                      Residence
# ...            ...                            ...
# 242929           1                      Residence
# 242931           1                      Residence
# 242936           1                      Residence
# 243005           1                      Residence
# 243015           1                      Residence
#
# [52872 rows x 16 columns]

# %%
#uses the FCC County Code TXT file to merge the values to the as the county_code as a new column county_name
county_mapping_df = pd.read_csv('county_codes.csv')

df = df.merge(county_mapping_df, on='county_code', how='left')

df = df.rename(columns={'county_name': 'county_name'})

#drops the now useless county_code
county_drop = ['county_code']

df = df.drop(columns=county_drop)

df
# Out:
#        activity_year     loan_type   loan_purpose construction_method  \
# 0               2022  Conventional  Home Purchase          Site-Built
# 1               2022  Conventional  Home Purchase          Site-Built
# 2               2022  Conventional  Home Purchase          Site-Built
# 3               2022  Conventional  Home Purchase          Site-Built
# 4               2022  Conventional  Home Purchase          Site-Built
# ...              ...           ...            ...                 ...
# 52867           2022  Conventional  Home Purchase          Site-Built
# 52868           2022  Conventional  Home Purchase          Site-Built
# 52869           2022  Conventional  Home Purchase          Site-Built
# 52870           2022  Conventional  Home Purchase          Site-Built
# 52871           2022  Conventional  Home Purchase          Site-Built
#
#             occupancy_type  loan_amount action_taken state_code    income  \
# 0      Principal-residence       415000     Approved         MI  119000.0
# 1      Principal-residence       405000     Approved         TX   97000.0
# 2      Principal-residence       375000     Approved         NY  152000.0
# 3      Principal-residence       265000     Approved         TX  138000.0
# 4      Principal-residence       225000     Approved         MO   89000.0
# ...                    ...          ...          ...        ...       ...
# 52867  Principal-residence       295000     Approved         FL   58000.0
# 52868  Principal-residence       205000     Approved         GA  258000.0
# 52869  Principal-residence       545000     Approved         AZ  310000.0
# 52870  Principal-residence       355000     Approved         CA  155000.0
# 52871  Principal-residence       345000     Approved         OR  132000.0
#
#        total_loan_costs  interest_rate  loan_term  property_value total_units  \
# 0               4414.66          5.875      360.0        435000.0           1
# 1               5230.50          3.500      360.0        425000.0           1
# 2               7841.13          2.875      360.0        505000.0           1
# 3              11698.72          3.875      360.0        335000.0           1
# 4               3848.86          4.125      360.0        255000.0           1
# ...                 ...            ...        ...             ...         ...
# 52867           8346.79          4.000      360.0        375000.0           1
# 52868           8361.45          4.125      360.0        385000.0           1
# 52869           5014.23          3.375      360.0        685000.0           1
# 52870           4647.45          4.750      360.0        975000.0           1
# 52871           8419.60          3.750      360.0        435000.0           1
#
#       business_or_commercial_purpose            county_name
# 0                          Residence        Macomb County
# 1                          Residence        Dallas County
# 2                          Residence         Kings County
# 3                          Residence        Harris County
# 4                          Residence    St. Charles County
# ...                              ...                    ...
# 52867                      Residence  Hillsborough County
# 52868                      Residence        Fulton County
# 52869                      Residence      Maricopa County
# 52870                      Residence    Santa Clara County
# 52871                      Residence       Douglas County
#
# [52872 rows x 16 columns]

# %%
#re-orders our data in a human reading friendly order.
data_order = [
    'activity_year',
    'loan_type',
    'action_taken',
    'loan_purpose',
    'business_or_commercial_purpose',
    'construction_method',
    'occupancy_type',
    'state_code',
    'county_name',
    'loan_amount',
    'income',
    'loan_term',
    'property_value',
    'total_units']

df = df[data_order]

df
# Out:
#        activity_year     loan_type action_taken   loan_purpose  \
# 0               2022  Conventional     Approved  Home Purchase
# 1               2022  Conventional     Approved  Home Purchase
# 2               2022  Conventional     Approved  Home Purchase
# 3               2022  Conventional     Approved  Home Purchase
# 4               2022  Conventional     Approved  Home Purchase
# ...              ...           ...          ...            ...
# 52867           2022  Conventional     Approved  Home Purchase
# 52868           2022  Conventional     Approved  Home Purchase
# 52869           2022  Conventional     Approved  Home Purchase
# 52870           2022  Conventional     Approved  Home Purchase
# 52871           2022  Conventional     Approved  Home Purchase
#
#       business_or_commercial_purpose construction_method       occupancy_type  \
# 0                          Residence          Site-Built  Principal-residence
# 1                          Residence          Site-Built  Principal-residence
# 2                          Residence          Site-Built  Principal-residence
# 3                          Residence          Site-Built  Principal-residence
# 4                          Residence          Site-Built  Principal-residence
# ...                              ...                 ...                  ...
# 52867                      Residence          Site-Built  Principal-residence
# 52868                      Residence          Site-Built  Principal-residence
# 52869                      Residence          Site-Built  Principal-residence
# 52870                      Residence          Site-Built  Principal-residence
# 52871                      Residence          Site-Built  Principal-residence
#
#       state_code            county_name  loan_amount    income  loan_term  \
# 0             MI        Macomb County         415000  119000.0      360.0
# 1             TX        Dallas County         405000   97000.0      360.0
# 2             NY         Kings County         375000  152000.0      360.0
# 3             TX        Harris County         265000  138000.0      360.0
# 4             MO    St. Charles County        225000   89000.0      360.0
# ...          ...                    ...          ...       ...        ...
# 52867         FL  Hillsborough County         295000   58000.0      360.0
# 52868         GA        Fulton County         205000  258000.0      360.0
# 52869         AZ      Maricopa County         545000  310000.0      360.0
# 52870         CA    Santa Clara County        355000  155000.0      360.0
# 52871         OR       Douglas County         345000  132000.0      360.0
#
#        property_value total_units
# 0            435000.0           1
# 1            425000.0           1
# 2            505000.0           1
# 3            335000.0           1
# 4            255000.0           1
# ...               ...         ...
# 52867        375000.0           1
# 52868        385000.0           1
# 52869        685000.0           1
# 52870        975000.0           1
# 52871        435000.0           1
#
# [52872 rows x 14 columns]

# %%
#Drops data with nothing so its not causing issues with the machine learning steps
df = df.dropna()

df
# Out:
#        activity_year     loan_type action_taken   loan_purpose  \
# 0               2022  Conventional     Approved  Home Purchase
# 1               2022  Conventional     Approved  Home Purchase
# 2               2022  Conventional     Approved  Home Purchase
# 3               2022  Conventional     Approved  Home Purchase
# 4               2022  Conventional     Approved  Home Purchase
# ...              ...           ...          ...            ...
# 52867           2022  Conventional     Approved  Home Purchase
# 52868           2022  Conventional     Approved  Home Purchase
# 52869           2022  Conventional     Approved  Home Purchase
# 52870           2022  Conventional     Approved  Home Purchase
# 52871           2022  Conventional     Approved  Home Purchase
#
#       business_or_commercial_purpose construction_method       occupancy_type  \
# 0                          Residence          Site-Built  Principal-residence
# 1                          Residence          Site-Built  Principal-residence
# 2                          Residence          Site-Built  Principal-residence
# 3                          Residence          Site-Built  Principal-residence
# 4                          Residence          Site-Built  Principal-residence
# ...                              ...                 ...                  ...
# 52867                      Residence          Site-Built  Principal-residence
# 52868                      Residence          Site-Built  Principal-residence
# 52869                      Residence          Site-Built  Principal-residence
# 52870                      Residence          Site-Built  Principal-residence
# 52871                      Residence          Site-Built  Principal-residence
#
#       state_code            county_name  loan_amount    income  loan_term  \
# 0             MI        Macomb County         415000  119000.0      360.0
# 1             TX        Dallas County         405000   97000.0      360.0
# 2             NY         Kings County         375000  152000.0      360.0
# 3             TX        Harris County         265000  138000.0      360.0
# 4             MO    St. Charles County        225000   89000.0      360.0
# ...          ...                    ...          ...       ...        ...
# 52867         FL  Hillsborough County         295000   58000.0      360.0
# 52868         GA        Fulton County         205000  258000.0      360.0
# 52869         AZ      Maricopa County         545000  310000.0      360.0
# 52870         CA    Santa Clara County        355000  155000.0      360.0
# 52871         OR       Douglas County         345000  132000.0      360.0
#
#        property_value total_units
# 0            435000.0           1
# 1            425000.0           1
# 2            505000.0           1
# 3            335000.0           1
# 4            255000.0           1
# ...               ...         ...
# 52867        375000.0           1
# 52868        385000.0           1
# 52869        685000.0           1
# 52870        975000.0           1
# 52871        435000.0           1
#
# [50095 rows x 14 columns]

# %%
#export to CSV

df.to_csv('export/2018_Chase_Loan_Tableau.csv', index=False)
#df.to_csv('export/2019_Chase_Loan_Tableau.csv', index=False)
#df.to_csv('export/2020_Chase_Loan_Tableau.csv', index=False)
#df.to_csv('export/2021_Chase_Loan_Tableau.csv', index=False)
#df.to_csv('export/2022_Chase_Loan_Tableau.csv', index=False)
